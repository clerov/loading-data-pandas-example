# %% [markdown]
# <center>
#
# ## Load Data Using Pandas from .csv/.txt/.json/.xlsx
#
# </center>

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data-comma-sep.txt',
#  'data-semicol.txt',
#  'data.csv',
#  'data.json',
#  'data.xlsx',
#  'load_data.ipynb',
#  'main.ipynb']

# %%
import pandas
import openpyxl

# %% [markdown]
# <center>
#
# #### Load data from .csv file
#
# </center>

# %%
df1 = pandas.read_csv('data.csv')
df1
# Out:
#         year      name   percent   sex
# 0       1880      John  0.081541   boy
# 1       1880   William  0.080511   boy
# 2       1880     James  0.050057   boy
# 3       1880   Charles  0.045167   boy
# 4       1880    George  0.043292   boy
# ...      ...       ...       ...   ...
# 257995  2008  Carleigh  0.000128  girl
# 257996  2008     Iyana  0.000128  girl
# 257997  2008    Kenley  0.000127  girl
# 257998  2008    Sloane  0.000127  girl
# 257999  2008   Elianna  0.000127  girl
#
# [258000 rows x 4 columns]

# %% [markdown]
# <center>
#
# #### Load data from json file
#
# </center>

# %%
df2 = pandas.read_json('data.json')
df2
# Out:
#    ID          Address           City             State Country         Name
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# <center>
#
# #### Load data from excel file
#
# </center>

# %%
openpyxl.open('data.xlsx')
df3 = pandas.read_excel('data.xlsx')
df3
# Out:
#      Unnamed: 0                        Unnamed: 1       Unnamed: 2 Unnamed: 3
# 0           NaN  List of Names for Excel Practice              NaN        NaN  \
# 1           NaN                               NaN              NaN        NaN
# 2           NaN         Problem 01 Join the Name:              NaN        NaN
# 3           NaN                        First Name      Middle Name  Last Name
# 4           NaN                             Brian          Charles       Lara
# ..          ...                               ...              ...        ...
# 275         NaN                       Christopher         Jonathan      Nolan
# 276         NaN                              Hans          Florian     Zimmer
# 277         NaN                               NaN              NaN        NaN
# 278         NaN                               NaN              NaN        NaN
# 279         NaN                         Name Part  Value from List        NaN
#
#     Unnamed: 4
# 0          NaN
# ...

# %% [markdown]
# <center>
#
# #### Load data from comma seperated text file
#
# </center>

# %%
df4 = pandas.read_csv('data-comma-sep.txt')
df4
# Out:
#     id     sex  glucose  insulin  triglyc
# 0  101    Male    134.1     0.60    273.4
# 1  102  Female    120.0     1.18    243.6
# 2  103    Male    124.8     1.23    297.6
# 3  104    Male     83.1     1.16    142.4
# 4  105    Male    105.2     0.73    215.7

# %% [markdown]
# <center>
#
# #### Load data from semicolon seperated files
#
# </center>

# %%
df5 = pandas.read_csv('data-semicol.txt', sep=";")
df5
# Out:
#     id     sex  glucose  insulin  triglyc
# 0  101    Male    134.1     0.60    273.4
# 1  102  Female    120.0     1.18    243.6
# 2  103    Male    124.8     1.23    297.6
# 3  104    Male     83.1     1.16    142.4
# 4  105    Male    105.2     0.73    215.7
